# %% [markdown]
# <a href="https://colab.research.google.com/github/nataliia82/goit_pandas_hw/blob/main/Pandas_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !wget https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2025.zip -O survey_2025.zip
# Out:
# --2025-10-09 17:35:14--  https://survey.stackoverflow.co/datasets/stack-overflow-developer-survey-2025.zip
# Resolving survey.stackoverflow.co (survey.stackoverflow.co)... 3.33.186.135, 15.197.167.90
# Connecting to survey.stackoverflow.co (survey.stackoverflow.co)|3.33.186.135|:443... connected.
# HTTP request sent, awaiting response... 429 Too Many Requests
# 2025-10-09 17:35:14 ERROR 429: Too Many Requests.

# %%
# !unzip -o survey_2025.zip -d survey_2025_data
# Out:
# Archive:  survey_2025.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of survey_2025.zip or
#         survey_2025.zip.zip, and cannot find survey_2025.zip.ZIP, period.

# %%
df = pd.read_csv("survey_2025_data/survey_results_public.csv")
df.head()
# Out:
#    ResponseId                      MainBranch              Age  \
# 0           1  I am a developer by profession  25-34 years old
# 1           2  I am a developer by profession  25-34 years old
# 2           3  I am a developer by profession  35-44 years old
# 3           4  I am a developer by profession  35-44 years old
# 4           5  I am a developer by profession  35-44 years old
#
#                                            EdLevel  \
# 0  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1              Associate degree (A.A., A.S., etc.)
# 2     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                           Employment  \
# 0                                           Employed
# 1                                           Employed
# 2  Independent contractor, freelancer, or self-em...
# 3                                           Employed
# ...

# %%
df.shape
# Out:
# (49123, 170)

# %%
print(f"1. Кількість респондентів, які пройшли опитування: {df.shape[0]}")
# Out:
# 1. Кількість респондентів, які пройшли опитування: 49123

# %%
schema = pd.read_csv("survey_2025_data/survey_results_schema.csv")
schema.head()
# Out:
#      qid          qname                                           question  \
# 0  QID18  TechEndorse_1  What attracts you to a technology or causes yo...
# 1  QID18  TechEndorse_2  What attracts you to a technology or causes yo...
# 2  QID18  TechEndorse_3  What attracts you to a technology or causes yo...
# 3  QID18  TechEndorse_4  What attracts you to a technology or causes yo...
# 4  QID18  TechEndorse_5  What attracts you to a technology or causes yo...
#
#   type                                      sub  sq_id
# 0   RO  AI integration or AI Agent capabilities    1.0
# 1   RO                          Easy-to-use API    2.0
# 2   RO                  Robust and complete API    3.0
# 3   RO     Customizable and manageable codebase    4.0
# 4   RO                   Reputation for quality    5.0

# %%
schema.shape
# Out:
# (139, 6)

# %%
question_cols = set(schema["qname"])
valid_cols = list(set(df.columns).intersection(question_cols))
df_questions = df[valid_cols]
complete_responses = df_questions.dropna().shape[0]
print(f"2. Кількість респондентів, які відповіли на всі запитання: {complete_responses}")
# Out:
# 2. Кількість респондентів, які відповіли на всі запитання: 0

# %%
mean_exp = df["WorkExp"].mean()
median_exp = df["WorkExp"].median()
mode_exp = df["WorkExp"].mode().iloc[0]

print("3. Значення мір центральної тенденції для досвіду (WorkExp) респондентів:")
print(f"Середнє значення досвіду: {mean_exp:.2f} років")
print(f"Медіана досвіду: {median_exp:.2f} років")
print(f"Мода досвіду: {mode_exp:.2f} років")
# Out:
# 3. Значення мір центральної тенденції для досвіду (WorkExp) респондентів:
# Середнє значення досвіду: 13.37 років
# Медіана досвіду: 10.00 років
# Мода досвіду: 10.00 років

# %%
remote_count = df[df["RemoteWork"].isin(["Remote", "Fully remote", "Hybrid"])].shape[0]
print(f"4. Кількість респондентів, які працюють віддалено або гібридно: {remote_count}")
# Out:
# 4. Кількість респондентів, які працюють віддалено або гібридно: 10924

# %%
python_count = df["LanguageHaveWorkedWith"].str.contains("Python", case=False, na=False).sum()
total_respondents = df["LanguageHaveWorkedWith"].notna().sum()
python_percent = (python_count / total_respondents) * 100

print(f"5. Python використовують {python_count} із {total_respondents} респондентів ({python_percent:.2f}%)")
# Out:
# 5. Python використовують 18444 із 31643 респондентів (58.29%)

# %%
online_count = df["LearnCode"].str.contains("online", case=False, na=False).sum()

print(f"6. Кількість респондентів, які навчалися програмувати через онлайн курси: {online_count}")
# Out:
# 6. Кількість респондентів, які навчалися програмувати через онлайн курси: 28313

# %%
python_df = df[df["LanguageHaveWorkedWith"].str.contains("Python", case=False, na=False)]
country_comp = python_df.groupby("Country")["ConvertedCompYearly"].agg(['mean', 'median']).reset_index()

print("7. Середня та медіанна сума компенсації (ConvertedCompYearly) в кожній країні (head(10)):")
print(country_comp.sort_values(by='mean', ascending=False).head(10))
# Out:
# 7. Середня та медіанна сума компенсації (ConvertedCompYearly) в кожній країні (head(10)):
#                       Country           mean    median
# 112                      Oman  390135.000000  390135.0
# 3                     Andorra  226103.500000  226103.5
# 163                  Viet Nam  218837.166667    8254.0
# 159  United States of America  173295.260243  150000.0
# 145               Switzerland  156456.600000  142592.0
# 134                 Singapore  147515.121951   91391.0
# 72                     Israel  135828.365385  142594.0
# 108                   Nigeria  128773.276596    1808.0
# 70                    Ireland  120523.918919  116015.0
# 109                   Nomadic  120131.571429  139218.0

# %%
df_comp = df.dropna(subset=["ConvertedCompYearly"])
df_top5 = df_comp.sort_values(by="ConvertedCompYearly", ascending=False).head(5)
print("8. Рівні освіти які мають 5 респондентів з найбільшою компенсацією:")
df_top5[["EdLevel"]]
# Out:
# 8. Рівні освіти які мають 5 респондентів з найбільшою компенсацією:
#                                                EdLevel
# 34267              Associate degree (A.A., A.S., etc.)
# 28700  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 43143              Associate degree (A.A., A.S., etc.)
# 35353     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 45971  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
